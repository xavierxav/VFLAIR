# %%
import numpy as np
import pandas as pd

# %%
file_path = 'load\share_dataset\satellite\satellite_party0_test.csv'

# %%
#load only the first 1000 rows
df = pd.read_csv(file_path, nrows=10, header=0 , delimiter=',' , dtype='int16')

# %%
#print df size in Mb
print(df.memory_usage(index=True).sum() / 1024**2)
# Out:
# 6.190116882324219

# %%
# drop id make y an int and all other columns floats with 1 decimal points to save storage
df = df.drop(columns=['id'])

# %%
print(df.memory_usage(index=True).sum() / 1024**2)
# Out:
# 6.190097808837891

# %%
df
# Out:
#    y   x0   x1   x2   x3   x4   x5   x6   x7   x8  ...  x324522  x324523  \
# 0  2   65   65   65   65   65   65   65   65   65  ...       38       38
# 1  3   97   97   97  102  102  102  102  102  101  ...      171      171
# 2  3   77   77   78   78   78   78   78   78   78  ...      142      145
# 3  3   94   94   94   94   91   91   91   91   91  ...       35       39
# 4  0  200  200  200  200  200  200  200  200  200  ...       75       76
# 5  2   66   66   66   66   66   66   67   67   67  ...       42       40
# 6  2   81   81   81   79   79   79   79   79   79  ...       77       69
# 7  2  156  155  155  155  155  155  154  146  147  ...       11       11
# 8  3   51   52   52   52   52   52   52   52   52  ...       35       35
# 9  3   98   98   98   98   98   98  101  102  102  ...      197      196
#
#    x324524  x324525  x324526  x324527  x324528  x324529  x324530  x324531
# 0       38       37       37       38       38       39       39       39
# ...
